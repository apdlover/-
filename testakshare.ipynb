# %%
import akshare as ak
print("--"*40 + "上海证券交易所-股票数据总貌" + "--"*40)
stock_sse_summary_df = ak.stock_sse_summary() #上海证券交易所-股票数据总貌
print(stock_sse_summary_df)

print("--"*40 + "深圳证券交易所-股票数据总貌" + "--"*40)

stock_szse_summary_df = ak.stock_szse_summary(date="20200619") #深圳证券交易所-市场总貌-证券类别统计
print(stock_szse_summary_df)
# Out:
# --------------------------------------------------------------------------------上海证券交易所-股票数据总貌--------------------------------------------------------------------------------
#       项目         股票         主板       科创板
# 0   流通股本   47416.01   45727.46   1688.56
# 1    总市值  526874.14  460626.12  66248.02
# 2  平均市盈率      13.71      12.70     47.86
# 3   上市公司       2286       1699       587
# 4   上市股票       2325       1738       587
# 5   流通市值  500392.35  448489.22  51903.12
# 6   报告时间   20250526   20250526  20250526
# 8    总股本   49393.63   47144.96   2248.67
# --------------------------------------------------------------------------------深圳证券交易所-股票数据总貌--------------------------------------------------------------------------------
#      证券类别    数量          成交金额           总市值          流通市值
# 0      股票  2284  4.647749e+11  2.706514e+13  2.104546e+13
# 1    主板A股   460  9.775950e+10  7.864787e+12  6.943990e+12
# 2    主板B股    46  8.626816e+07  4.759658e+10  4.706385e+10
# ...
