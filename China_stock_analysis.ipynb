# %%
pip install pandas akshare loguru
# Out:
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (2.2.2)
# Collecting akshare
#   Downloading akshare-1.16.95-py3-none-any.whl.metadata (11 kB)
# Collecting loguru
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2023.3)
# Collecting aiohttp>=3.11.13 (from akshare)
#   Downloading aiohttp-3.12.0-cp312-cp312-win_amd64.whl.metadata (7.9 kB)
# Requirement already satisfied: beautifulsoup4>=4.9.1 in c:\users\admin\anaconda3\lib\site-packages (from akshare) (4.12.3)
# Requirement already satisfied: lxml>=4.2.1 in c:\users\admin\anaconda3\lib\site-packages (from akshare) (5.2.1)
# Requirement already satisfied: requests>=2.22.0 in c:\users\admin\anaconda3\lib\site-packages (from akshare) (2.32.3)
# Collecting html5lib>=1.0.1 (from akshare)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting xlrd>=1.2.0 (from akshare)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: urllib3>=1.25.8 in c:\users\admin\anaconda3\lib\site-packages (from akshare) (2.2.3)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\admin\anaconda3\lib\site-packages (from akshare) (4.66.5)
# Requirement already satisfied: openpyxl>=3.0.3 in c:\users\admin\anaconda3\lib\site-packages (from akshare) (3.1.5)
# Collecting jsonpath>=0.82 (from akshare)
#   Downloading jsonpath-0.82.2.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tabulate>=0.8.6 in c:\users\admin\anaconda3\lib\site-packages (from akshare) (0.9.0)
# Requirement already satisfied: decorator>=4.4.2 in c:\users\admin\anaconda3\lib\site-packages (from akshare) (5.1.1)
# Requirement already satisfied: nest_asyncio>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from akshare) (1.6.0)
# Collecting mini-racer>=0.12.4 (from akshare)
#   Downloading mini_racer-0.12.4-py3-none-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\admin\anaconda3\lib\site-packages (from loguru) (0.4.6)
# Collecting win32-setctime>=1.0.0 (from loguru)
#   Downloading win32_setctime-1.2.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp>=3.11.13->akshare)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp>=3.11.13->akshare) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp>=3.11.13->akshare) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp>=3.11.13->akshare) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp>=3.11.13->akshare) (6.0.4)
# Collecting propcache>=0.2.0 (from aiohttp>=3.11.13->akshare)
#   Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.11.13->akshare)
#   Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl.metadata (74 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\lib\site-packages (from beautifulsoup4>=4.9.1->akshare) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\admin\anaconda3\lib\site-packages (from html5lib>=1.0.1->akshare) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\admin\anaconda3\lib\site-packages (from html5lib>=1.0.1->akshare) (0.5.1)
# Requirement already satisfied: et-xmlfile in c:\users\admin\anaconda3\lib\site-packages (from openpyxl>=3.0.3->akshare) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.22.0->akshare) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.22.0->akshare) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.22.0->akshare) (2025.4.26)
# Downloading akshare-1.16.95-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 10.1 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
# Downloading aiohttp-3.12.0-cp312-cp312-win_amd64.whl (435 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading mini_racer-0.12.4-py3-none-win_amd64.whl (13.7 MB)
#    ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#    ------ --------------------------------- 2.4/13.7 MB 16.8 MB/s eta 0:00:01
#    --------------- ------------------------ 5.2/13.7 MB 13.3 MB/s eta 0:00:01
#    ------------------------- -------------- 8.7/13.7 MB 14.5 MB/s eta 0:00:01
#    ------------------------------------- -- 12.8/13.7 MB 15.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.7/13.7 MB 15.3 MB/s eta 0:00:00
# Downloading win32_setctime-1.2.0-py3-none-any.whl (4.1 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl (44 kB)
# Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl (92 kB)
# Building wheels for collected packages: jsonpath
#   Building wheel for jsonpath (setup.py): started
#   Building wheel for jsonpath (setup.py): finished with status 'done'
#   Created wheel for jsonpath: filename=jsonpath-0.82.2-py3-none-any.whl size=5627 sha256=3843c6f023d6a83bc996d8ab965338d6cb4f2555ff93079d37f58b8db196b119
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\73\76\e2\980a29341fe37a583ada29594ed529708d5e8e2c0f9d97c3cc
# Successfully built jsonpath
# Installing collected packages: jsonpath, xlrd, win32-setctime, propcache, mini-racer, html5lib, aiohappyeyeballs, yarl, loguru, aiohttp, akshare
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.4.0
#     Uninstalling aiohappyeyeballs-2.4.0:
#       Successfully uninstalled aiohappyeyeballs-2.4.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.11.0
#     Uninstalling yarl-1.11.0:
#       Successfully uninstalled yarl-1.11.0
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.10.5
#     Uninstalling aiohttp-3.10.5:
#       Successfully uninstalled aiohttp-3.10.5
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.0 akshare-1.16.95 html5lib-1.1 jsonpath-0.82.2 loguru-0.7.3 mini-racer-0.12.4 propcache-0.3.1 win32-setctime-1.2.0 xlrd-2.0.1 yarl-1.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
import os
import time
from datetime import datetime
import json
from pathlib import Path
import random
import logging

# 设置中文显示
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]
plt.rcParams["axes.unicode_minus"] = False  # 解决负号显示问题

# 配置日志
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("stock_analysis.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

class ChinaStockAnalyzer:
    def __init__(self, data_dir="data", output_dir="output", use_proxy=False):
        """初始化分析器，设定数据存储和输出目录"""
        self.data_dir = self._normalize_path(data_dir)
        self.output_dir = self._normalize_path(output_dir)
        self.sse_url = "http://www.sse.com.cn/market/stockdata/statistic/"
        self.szse_url = "http://www.szse.cn/market/overview/index.html"
        self.bse_url = "https://www.bse.cn/static/statisticdata.html"
        self.bse_stat_url = "https://www.bse.cn/static/statisticdata.html"
        self.use_proxy = use_proxy
        
        # 常用请求头，模拟浏览器行为
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8',
            'Connection': 'keep-alive',
        }
        
        # 可选代理池（需要自己准备可用的代理）
        self.proxies = [
            # 格式: {"http": "http://user:pass@ip:port", "https": "http://user:pass@ip:port"}
        ]
        
        # 确保目录存在
        self._ensure_directory_exists(self.data_dir)
        self._ensure_directory_exists(self.output_dir)
        
        # 初始化数据存储
        self.data = {}
    
    def _normalize_path(self, path):
        """标准化路径，确保跨平台一致性"""
        return os.path.abspath(os.path.expanduser(path))
    
    def _ensure_directory_exists(self, dir_path):
        """确保目录存在，如果不存在则创建它"""
        dir_path = self._normalize_path(dir_path)
        
        logger.info(f"检查目录: {dir_path}")
        
        if os.path.exists(dir_path):
            # 路径已存在，检查是否为目录
            if not os.path.isdir(dir_path):
                logger.warning(f"警告: 路径存在但不是目录: {dir_path}")
                
                try:
                    logger.info(f"尝试删除非目录对象: {dir_path}")
                    os.remove(dir_path)
                    logger.info(f"成功删除非目录对象")
                    
                    # 创建目录
                    os.makedirs(dir_path, exist_ok=True)
                    logger.info(f"成功创建目录: {dir_path}")
                except Exception as e:
                    raise OSError(f"无法删除已存在的非目录对象: {dir_path}, 错误: {e}")
            else:
                # 是目录，检查权限
                self._check_directory_permissions(dir_path)
                logger.info(f"目录已存在且可写: {dir_path}")
        else:
            # 路径不存在，创建目录
            try:
                logger.info(f"目录不存在，正在创建: {dir_path}")
                os.makedirs(dir_path, exist_ok=True)
                logger.info(f"成功创建目录: {dir_path}")
                
                # 验证目录是否真的存在
                if not os.path.exists(dir_path):
                    raise OSError(f"目录创建失败，但没有抛出异常: {dir_path}")
                
                # 检查目录权限
                self._check_directory_permissions(dir_path)
                
            except Exception as e:
                logger.error(f"创建目录 {dir_path} 失败: {e}")
                
                # 尝试创建父目录
                parent_dir = os.path.dirname(dir_path)
                if parent_dir and not os.path.exists(parent_dir):
                    logger.info(f"尝试创建父目录: {parent_dir}")
                    try:
                        os.makedirs(parent_dir, exist_ok=True)
                        logger.info(f"成功创建父目录: {parent_dir}")
                        
                        # 再次尝试创建目标目录
                        os.makedirs(dir_path, exist_ok=True)
                        logger.info(f"成功创建目录: {dir_path}")
                    except Exception as e2:
                        logger.error(f"创建父目录 {parent_dir} 失败: {e2}")
                        raise
                else:
                    raise
    
    def _check_directory_permissions(self, dir_path):
        """检查目录是否有写入权限"""
        # 尝试创建一个临时文件测试写入权限
        test_file = os.path.join(dir_path, ".permission_test.tmp")
        try:
            with open(test_file, 'w') as f:
                f.write("test")
            os.remove(test_file)
            logger.info(f"目录写入权限检查通过: {dir_path}")
        except Exception as e:
            # 获取当前用户信息
            user_info = "未知用户"
            try:
                if os.name == 'nt':  # Windows
                    import getpass
                    user_info = getpass.getuser()
                else:  # Linux/macOS
                    import pwd
                    user_info = pwd.getpwuid(os.getuid()).pw_name
            except:
                pass
            
            # 获取目录权限信息
            permissions = "未知权限"
            try:
                if os.name != 'nt':  # 非Windows系统
                    permissions = oct(os.stat(dir_path).st_mode & 0o777)
            except:
                pass
            
            raise OSError(f"""
                目录没有写入权限: {dir_path}
                用户: {user_info}
                目录权限: {permissions}
                
                解决方案:
                1. 检查目录是否被其他程序占用
                2. 修改目录权限 (Windows: 取消只读属性; Linux/macOS: chmod 755)
                3. 以管理员/root权限运行程序
            """)
    
    def _make_request(self, url, retries=3, timeout=10):
        """发送HTTP请求，处理重试和异常"""
        for attempt in range(retries):
            try:
                # 随机延时，避免请求过于频繁
                wait_time = random.uniform(1, 3)
                logger.info(f"等待 {wait_time:.2f} 秒后请求: {url}")
                time.sleep(wait_time)
                
                # 选择请求配置
                request_kwargs = {
                    'headers': self.headers,
                    'timeout': timeout
                }
                
                # 如果启用代理，随机选择一个
                if self.use_proxy and self.proxies:
                    proxy = random.choice(self.proxies)
                    request_kwargs['proxies'] = proxy
                    logger.info(f"使用代理: {proxy.get('https', proxy.get('http'))}")
                
                # 发送请求
                response = requests.get(url, **request_kwargs)
                response.raise_for_status()  # 检查HTTP状态码
                
                # 检查内容是否有效
                if len(response.text) < 100:  # 内容过短可能表示有问题
                    raise ValueError(f"响应内容过短: {len(response.text)} 字节")
                
                return response
            
            except requests.exceptions.HTTPError as e:
                if response.status_code == 403:
                    logger.warning(f"请求被拒绝 (403): {url}")
                    # 403错误可能需要更长的等待时间
                    time.sleep(10 + attempt * 5)
                elif response.status_code == 429:
                    logger.warning(f"请求过多 (429): {url}")
                    time.sleep(30 + attempt * 10)  # 指数退避
                else:
                    logger.error(f"HTTP错误 {response.status_code}: {url}")
                
                if attempt == retries - 1:
                    raise
            
            except Exception as e:
                logger.error(f"请求出错 ({attempt+1}/{retries}): {e}")
                if attempt == retries - 1:
                    raise
    
    def fetch_sse_data(self):
        """获取上海证券交易所数据"""
        logger.info("正在获取上海证券交易所数据...")
        try:
            response = self._make_request(self.sse_url)
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # 实际的网页解析逻辑需要根据上交所网站的实际结构进行调整
            sse_data = {}
            
            # 查找总览表格
            overview_table = None
            for table in soup.find_all('table'):
                if "上市公司数" in table.text:
                    overview_table = table
                    break
            
            if overview_table:
                rows = overview_table.find_all('tr')
                for row in rows[1:]:  # 跳过表头
                    cells = row.find_all('td')
                    if len(cells) >= 3:
                        market = cells[0].text.strip()
                        company_count = cells[1].text.strip()
                        total_cap = cells[2].text.strip()
                        
                        # 处理年份（假设表格按年份排序，最新的在最前面）
                        year = datetime.now().year
                        
                        if market in ["主板", "科创板"]:
                            if year not in sse_data:
                                sse_data[year] = {}
                            sse_data[year][market] = int(company_count.replace(',', ''))
            
            self.data["sse"] = sse_data
            logger.info(f"上海证券交易所数据获取完成: {sse_data}")
            return sse_data
            
        except Exception as e:
            logger.error(f"获取上海证券交易所数据时出错: {e}")
            return {}
    
    def fetch_szse_data(self):
        """获取深圳证券交易所数据"""
        logger.info("正在获取深圳证券交易所数据...")
        try:
            response = self._make_request(self.szse_url)
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # 实际的网页解析逻辑需要根据深交所网站的实际结构进行调整
            szse_data = {}
            
            # 查找包含上市公司数量的表格或区块
            # 示例：查找包含"上市公司家数"的元素
            company_count_elements = soup.find_all(lambda tag: "上市公司家数" in tag.text)
            
            if company_count_elements:
                # 假设第一个找到的元素包含我们需要的数据
                parent_div = company_count_elements[0].parent
                count_text = parent_div.find('span').text.strip() if parent_div else "0"
                
                # 获取年份
                year = datetime.now().year
                szse_data[year] = {"总计": int(count_text.replace(',', ''))}
                
                # 尝试提取各板块数据
                # ... 实际代码需要根据网站结构调整
                
            self.data["szse"] = szse_data
            logger.info(f"深圳证券交易所数据获取完成: {szse_data}")
            return szse_data
            
        except Exception as e:
            logger.error(f"获取深圳证券交易所数据时出错: {e}")
            return {}
    
    def fetch_bse_data(self):
        """获取北京证券交易所数据"""
        logger.info("正在获取北京证券交易所数据...")
        try:
            # 先请求主页，获取cookies和其他必要信息
            self._make_request("https://www.bse.cn/")
            
            # 再请求统计数据页面
            response = self._make_request(self.bse_url)
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # 实际的网页解析逻辑需要根据北交所网站的实际结构进行调整
            bse_data = {}
            
            # 查找上市公司数量
            company_count = 0
            
            # 示例：查找包含"上市公司家数"的元素
            count_elements = soup.find_all(lambda tag: "上市公司家数" in tag.text)
            
            if count_elements:
                # 提取数量
                count_text = count_elements[0].parent.text.strip() if count_elements[0].parent else "0"
                count_text = count_text.replace("上市公司家数", "").replace("家", "").strip()
                company_count = int(count_text)
                
                # 获取年份
                year = datetime.now().year
                bse_data[year] = {"总计": company_count}
            
            # 尝试从统计页面获取更多数据
            try:
                response_stat = self._make_request(self.bse_stat_url)
                soup_stat = BeautifulSoup(response_stat.text, 'html.parser')
                
                # 提取统计数据
                # ... 实际代码需要根据网站结构调整
                
            except Exception as e:
                logger.warning(f"获取北交所统计数据页面时出错: {e}")
            
            self.data["bse"] = bse_data
            logger.info(f"北京证券交易所数据获取完成: {bse_data}")
            return bse_data
            
        except Exception as e:
            logger.error(f"获取北京证券交易所数据时出错: {e}")
            return {}
    
    def fetch_industry_data(self):
        """获取行业分布数据"""
        logger.info("正在获取行业分布数据...")
        try:
            industry_data = {
                "sse": {},
                "szse": {},
                "bse": {}
            }
            
            # 获取上交所行业分布
            try:
                sse_industry_url = "http://www.sse.com.cn/market/stockdata/industry/"
                response = self._make_request(sse_industry_url)
                soup = BeautifulSoup(response.text, 'html.parser')
                
                # 解析行业分布数据
                industry_table = soup.find('table', class_='tableA')
                if industry_table:
                    rows = industry_table.find_all('tr')
                    for row in rows[1:]:  # 跳过表头
                        cells = row.find_all('td')
                        if len(cells) >= 3:
                            industry = cells[0].text.strip()
                            company_count = cells[1].text.strip()
                            industry_data["sse"][industry] = int(company_count.replace(',', ''))
            
            except Exception as e:
                logger.error(f"获取上交所行业分布数据时出错: {e}")
                # 使用默认数据
                industry_data["sse"] = {"金融": 100, "制造业": 80, "信息技术": 60, "房地产": 40}
            
            # 获取深交所行业分布
            try:
                szse_industry_url = "http://www.szse.cn/market/overview/industry.html"
                response = self._make_request(szse_industry_url)
                soup = BeautifulSoup(response.text, 'html.parser')
                
                # 解析行业分布数据
                # ... 实际代码需要根据网站结构调整
                
            except Exception as e:
                logger.error(f"获取深交所行业分布数据时出错: {e}")
                # 使用默认数据
                industry_data["szse"] = {"制造业": 120, "信息技术": 90, "医药生物": 70, "金融": 50}
            
            # 获取北交所行业分布
            try:
                bse_industry_url = "https://www.bse.cn/disclosure/listedcompanyindustry.html"
                response = self._make_request(bse_industry_url)
                soup = BeautifulSoup(response.text, 'html.parser')
                
                # 解析行业分布数据
                # ... 实际代码需要根据网站结构调整
                
            except Exception as e:
                logger.error(f"获取北交所行业分布数据时出错: {e}")
                # 使用默认数据
                industry_data["bse"] = {"信息技术": 30, "制造业": 40, "材料": 20, "机械设备": 15}
            
            self.data["industry"] = industry_data
            logger.info("行业分布数据获取完成")
            return industry_data
            
        except Exception as e:
            logger.error(f"获取行业分布数据时出错: {e}")
            return {
                "sse": {"金融": 100, "制造业": 80, "信息技术": 60, "房地产": 40},
                "szse": {"制造业": 120, "信息技术": 90, "医药生物": 70, "金融": 50},
                "bse": {"信息技术": 30, "制造业": 40, "材料": 20, "机械设备": 15}
            }
    
    def save_data(self):
        """保存获取的数据到文件"""
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        data_file = os.path.join(self.data_dir, f"stock_data_{timestamp}.json")
        
        # 确保目录存在
        self._ensure_directory_exists(os.path.dirname(data_file))
        
        with open(data_file, 'w', encoding='utf-8') as f:
            json.dump(self.data, f, ensure_ascii=False, indent=4)
        
        logger.info(f"数据已保存到 {data_file}")
    
    def analyze_total_companies(self):
        """分析各年度上市公司总数"""
        logger.info("分析各年度上市公司总数...")
        
        # 整合各交易所数据
        years = []
        total_companies = []
        
        # 获取所有可能的年份
        all_years = set()
        for exchange in ["sse", "szse", "bse"]:
            if exchange in self.data and self.data[exchange]:
                all_years.update(self.data[exchange].keys())
        
        # 按年份统计总数
        for year in sorted(all_years):
            total = 0
            for exchange in ["sse", "szse", "bse"]:
                if exchange in self.data and year in self.data[exchange]:
                    # 累加该交易所该年份的所有板块公司数
                    total += sum(self.data[exchange][year].values())
            
            years.append(year)
            total_companies.append(total)
        
        # 创建数据框
        total_df = pd.DataFrame({
            "年份": years,
            "上市公司总数": total_companies
        })
        
        # 保存结果
        output_file = os.path.join(self.output_dir, "total_companies.csv")
        self._ensure_directory_exists(os.path.dirname(output_file))
        total_df.to_csv(output_file, index=False)
        
        # 可视化
        plt.figure(figsize=(10, 6))
        bars = plt.bar(years, total_companies, color='skyblue')
        plt.title('各年度上市公司总数')
        plt.xlabel('年份')
        plt.ylabel('公司数量')
        plt.xticks(years)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        
        # 为每个柱子添加数值标签
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2., height + 10,
                    f'{height}', ha='center', va='bottom')
        
        # 保存图表
        chart_file = os.path.join(self.output_dir, "total_companies.png")
        self._ensure_directory_exists(os.path.dirname(chart_file))
        plt.savefig(chart_file, dpi=300, bbox_inches='tight')
        plt.close()
        
        logger.info(f"各年度上市公司总数分析完成，结果已保存到 {output_file} 和 {chart_file}")
        return total_df
    
    def analyze_by_exchange(self):
        """按交易所分析上市公司数量"""
        logger.info("按交易所分析上市公司数量...")
        
        # 整合各交易所数据
        years = []
        sse_counts = []
        szse_counts = []
        bse_counts = []
        
        # 获取所有可能的年份
        all_years = set()
        for exchange in ["sse", "szse", "bse"]:
            if exchange in self.data and self.data[exchange]:
                all_years.update(self.data[exchange].keys())
        
        # 按年份统计各交易所公司数
        for year in sorted(all_years):
            sse_count = sum(self.data["sse"][year].values()) if "sse" in self.data and year in self.data["sse"] else 0
            szse_count = sum(self.data["szse"][year].values()) if "szse" in self.data and year in self.data["szse"] else 0
            bse_count = sum(self.data["bse"][year].values()) if "bse" in self.data and year in self.data["bse"] else 0
            
            years.append(year)
            sse_counts.append(sse_count)
            szse_counts.append(szse_count)
            bse_counts.append(bse_count)
        
        # 创建数据框
        exchange_df = pd.DataFrame({
            "年份": years,
            "上交所": sse_counts,
            "深交所": szse_counts,
            "北交所": bse_counts
        })
        
        # 保存结果
        output_file = os.path.join(self.output_dir, "companies_by_exchange.csv")
        self._ensure_directory_exists(os.path.dirname(output_file))
        exchange_df.to_csv(output_file, index=False)
        
        # 可视化
        plt.figure(figsize=(12, 7))
        x = np.arange(len(years))
        width = 0.25
        
        plt.bar(x - width, sse_counts, width, label='上交所', color='skyblue')
        plt.bar(x, szse_counts, width, label='深交所', color='lightgreen')
        plt.bar(x + width, bse_counts, width, label='北交所', color='salmon')
        
        plt.title('各交易所上市公司数量对比')
        plt.xlabel('年份')
        plt.ylabel('公司数量')
        plt.xticks(x, years)
        plt.legend()
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        
        # 保存图表
        chart_file = os.path.join(self.output_dir, "companies_by_exchange.png")
        self._ensure_directory_exists(os.path.dirname(chart_file))
        plt.savefig(chart_file, dpi=300, bbox_inches='tight')
        plt.close()
        
        logger.info(f"按交易所分析完成，结果已保存到 {output_file} 和 {chart_file}")
        return exchange_df
    
    def analyze_industry_distribution(self):
        """分析行业分布"""
        logger.info("分析行业分布...")
        
        industry_data = self.data.get("industry", {})
        
        for exchange, data in industry_data.items():
            if not data:
                continue
                
            # 创建数据框
            industry_df = pd.DataFrame({
                "行业": list(data.keys()),
                "公司数量": list(data.values())
            })
            
            # 保存结果
            output_file = os.path.join(self.output_dir, f"industry_distribution_{exchange}.csv")
            self._ensure_directory_exists(os.path.dirname(output_file))
            industry_df.to_csv(output_file, index=False)
            
            # 可视化
            plt.figure(figsize=(12, 7))
            bars = plt.bar(data.keys(), data.values(), color='lightblue')
            plt.title(f'{exchange.upper()}上市公司行业分布')
            plt.xlabel('行业')
            plt.ylabel('公司数量')
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            
            # 为每个柱子添加数值标签
            for bar in bars:
                height = bar.get_height()
                plt.text(bar.get_x() + bar.get_width()/2., height + 1,
                        f'{height}', ha='center', va='bottom')
            
            # 保存图表
            chart_file = os.path.join(self.output_dir, f"industry_distribution_{exchange}.png")
            self._ensure_directory_exists(os.path.dirname(chart_file))
            plt.savefig(chart_file, dpi=300, bbox_inches='tight')
            plt.close()
        
        logger.info(f"行业分布分析完成，结果已保存到 {self.output_dir} 目录")
        return industry_data
    
    def run_analysis(self):
        """运行完整的分析流程"""
        logger.info("=" * 50)
        logger.info("开始中国上市公司数量年度统计分析...")
        logger.info(f"数据目录: {self.data_dir}")
        logger.info(f"输出目录: {self.output_dir}")
        logger.info("=" * 50)
        
        # 获取数据
        self.fetch_sse_data()
        self.fetch_szse_data()
        self.fetch_bse_data()
        self.fetch_industry_data()
        
        # 保存原始数据
        self.save_data()
        
        # 数据分析
        total_df = self.analyze_total_companies()
        exchange_df = self.analyze_by_exchange()
        industry_data = self.analyze_industry_distribution()
        
        logger.info("=" * 50)
        logger.info("分析完成！所有结果已保存到 output 目录")
        logger.info("=" * 50)
        
        # 返回主要结果
        return {
            "total_companies": total_df,
            "companies_by_exchange": exchange_df,
            "industry_distribution": industry_data
        }

if __name__ == "__main__":
    # 示例：使用自定义目录和代理
    analyzer = ChinaStockAnalyzer(
        data_dir="data",
        output_dir="output",
        use_proxy=False  # 设置为True并配置proxies属性以使用代理
    )
    results = analyzer.run_analysis()
# Out:
# 2025-05-25 21:54:47,583 - __main__ - INFO - 检查目录: d:\ifindata\第一次小组作业\data
# 2025-05-25 21:54:47,584 - __main__ - INFO - 目录写入权限检查通过: d:\ifindata\第一次小组作业\data
# 2025-05-25 21:54:47,584 - __main__ - INFO - 目录已存在且可写: d:\ifindata\第一次小组作业\data
# 2025-05-25 21:54:47,584 - __main__ - INFO - 检查目录: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:54:47,585 - __main__ - INFO - 目录写入权限检查通过: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:54:47,585 - __main__ - INFO - 目录已存在且可写: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:54:47,586 - __main__ - INFO - ==================================================
# 2025-05-25 21:54:47,586 - __main__ - INFO - 开始中国上市公司数量年度统计分析...
# 2025-05-25 21:54:47,586 - __main__ - INFO - 数据目录: d:\ifindata\第一次小组作业\data
# 2025-05-25 21:54:47,587 - __main__ - INFO - 输出目录: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:54:47,587 - __main__ - INFO - ==================================================
# 2025-05-25 21:54:47,588 - __main__ - INFO - 正在获取上海证券交易所数据...
# 2025-05-25 21:54:47,588 - __main__ - INFO - 等待 2.20 秒后请求: http://www.sse.com.cn/market/stockdata/statistic/
# 2025-05-25 21:54:49,874 - __main__ - INFO - 上海证券交易所数据获取完成: {}
# 2025-05-25 21:54:49,875 - __main__ - INFO - 正在获取深圳证券交易所数据...
# 2025-05-25 21:54:49,875 - __main__ - INFO - 等待 1.78 秒后请求: http://www.szse.cn/market/overview/index.html
# 2025-05-25 21:54:51,711 - __main__ - INFO - 深圳证券交易所数据获取完成: {}
# 2025-05-25 21:54:51,711 - __main__ - INFO - 正在获取北京证券交易所数据...
# 2025-05-25 21:54:51,711 - __main__ - INFO - 等待 2.26 秒后请求: https://www.bse.cn/
# 2025-05-25 21:54:54,053 - __main__ - INFO - 等待 1.56 秒后请求: https://www.bse.cn/static/statisticdata.html
# 2025-05-25 21:54:55,852 - __main__ - INFO - 等待 2.32 秒后请求: https://www.bse.cn/static/statisticdata.html
# 2025-05-25 21:54:58,396 - __main__ - INFO - 北京证券交易所数据获取完成: {}
# 2025-05-25 21:54:58,396 - __main__ - INFO - 正在获取行业分布数据...
# 2025-05-25 21:54:58,397 - __main__ - INFO - 等待 1.50 秒后请求: http://www.sse.com.cn/market/stockdata/industry/
# 2025-05-25 21:54:59,982 - __main__ - ERROR - HTTP错误 404: http://www.sse.com.cn/market/stockdata/industry/
# 2025-05-25 21:54:59,982 - __main__ - INFO - 等待 2.58 秒后请求: http://www.sse.com.cn/market/stockdata/industry/
# 2025-05-25 21:55:02,670 - __main__ - ERROR - HTTP错误 404: http://www.sse.com.cn/market/stockdata/industry/
# 2025-05-25 21:55:02,671 - __main__ - INFO - 等待 2.83 秒后请求: http://www.sse.com.cn/market/stockdata/industry/
# 2025-05-25 21:55:05,579 - __main__ - ERROR - HTTP错误 404: http://www.sse.com.cn/market/stockdata/industry/
# 2025-05-25 21:55:05,579 - __main__ - ERROR - 获取上交所行业分布数据时出错: 404 Client Error: Not Found for url: http://www.sse.com.cn/market/stockdata/industry/
# 2025-05-25 21:55:05,580 - __main__ - INFO - 等待 2.32 秒后请求: http://www.szse.cn/market/overview/industry.html
# 2025-05-25 21:55:07,930 - __main__ - ERROR - HTTP错误 404: http://www.szse.cn/market/overview/industry.html
# 2025-05-25 21:55:07,931 - __main__ - INFO - 等待 2.16 秒后请求: http://www.szse.cn/market/overview/industry.html
# 2025-05-25 21:55:10,126 - __main__ - ERROR - HTTP错误 404: http://www.szse.cn/market/overview/industry.html
# 2025-05-25 21:55:10,126 - __main__ - INFO - 等待 2.79 秒后请求: http://www.szse.cn/market/overview/industry.html
# 2025-05-25 21:55:12,971 - __main__ - ERROR - HTTP错误 404: http://www.szse.cn/market/overview/industry.html
# 2025-05-25 21:55:12,973 - __main__ - ERROR - 获取深交所行业分布数据时出错: 404 Client Error: Not Found for url: http://www.szse.cn/market/overview/industry.html
# 2025-05-25 21:55:12,975 - __main__ - INFO - 等待 1.04 秒后请求: https://www.bse.cn/disclosure/listedcompanyindustry.html
# 2025-05-25 21:55:14,239 - __main__ - ERROR - HTTP错误 404: https://www.bse.cn/disclosure/listedcompanyindustry.html
# 2025-05-25 21:55:14,240 - __main__ - INFO - 等待 1.32 秒后请求: https://www.bse.cn/disclosure/listedcompanyindustry.html
# 2025-05-25 21:55:15,750 - __main__ - ERROR - HTTP错误 404: https://www.bse.cn/disclosure/listedcompanyindustry.html
# 2025-05-25 21:55:15,754 - __main__ - INFO - 等待 1.22 秒后请求: https://www.bse.cn/disclosure/listedcompanyindustry.html
# 2025-05-25 21:55:17,271 - __main__ - ERROR - HTTP错误 404: https://www.bse.cn/disclosure/listedcompanyindustry.html
# 2025-05-25 21:55:17,274 - __main__ - ERROR - 获取北交所行业分布数据时出错: 404 Client Error: Not Found for url: https://www.bse.cn/disclosure/listedcompanyindustry.html
# 2025-05-25 21:55:17,276 - __main__ - INFO - 行业分布数据获取完成
# 2025-05-25 21:55:17,279 - __main__ - INFO - 检查目录: d:\ifindata\第一次小组作业\data
# 2025-05-25 21:55:17,286 - __main__ - INFO - 目录写入权限检查通过: d:\ifindata\第一次小组作业\data
# 2025-05-25 21:55:17,288 - __main__ - INFO - 目录已存在且可写: d:\ifindata\第一次小组作业\data
# 2025-05-25 21:55:17,292 - __main__ - INFO - 数据已保存到 d:\ifindata\第一次小组作业\data\stock_data_20250525_215517.json
# 2025-05-25 21:55:17,293 - __main__ - INFO - 分析各年度上市公司总数...
# 2025-05-25 21:55:17,295 - __main__ - INFO - 检查目录: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,304 - __main__ - INFO - 目录写入权限检查通过: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,305 - __main__ - INFO - 目录已存在且可写: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,318 - __main__ - INFO - 检查目录: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,320 - __main__ - INFO - 目录写入权限检查通过: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,320 - __main__ - INFO - 目录已存在且可写: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,333 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,334 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,335 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,335 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,337 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,337 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,338 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,339 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,340 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,341 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,343 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,343 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,346 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,347 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,349 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,349 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,350 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,351 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,354 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,354 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,381 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,382 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,383 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,384 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,385 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,386 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,387 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,388 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,390 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,390 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,392 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,392 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,396 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,397 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,399 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,399 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,400 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,401 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,405 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,406 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,407 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,408 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,411 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,412 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,414 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,415 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,417 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,418 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,419 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,420 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,422 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,423 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,427 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,428 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,430 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,431 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,573 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,575 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,576 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,576 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,578 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,578 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,580 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,580 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,582 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,582 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,584 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,585 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,587 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,588 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,589 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,602 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,603 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,614 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,617 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,618 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,619 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,620 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,623 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,626 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,629 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,629 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,631 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,631 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,633 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,633 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,635 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,635 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,640 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,640 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,642 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,643 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,645 - __main__ - INFO - 各年度上市公司总数分析完成，结果已保存到 d:\ifindata\第一次小组作业\output\total_companies.csv 和 d:\ifindata\第一次小组作业\output\total_companies.png
# 2025-05-25 21:55:17,645 - __main__ - INFO - 按交易所分析上市公司数量...
# 2025-05-25 21:55:17,646 - __main__ - INFO - 检查目录: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,648 - __main__ - INFO - 目录写入权限检查通过: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,648 - __main__ - INFO - 目录已存在且可写: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,660 - __main__ - INFO - 检查目录: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,662 - __main__ - INFO - 目录写入权限检查通过: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,662 - __main__ - INFO - 目录已存在且可写: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:17,681 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,682 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,683 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,683 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,685 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,685 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,686 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,687 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,688 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,688 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,690 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,690 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,693 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,694 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,695 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,696 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,697 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,697 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,700 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,701 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,708 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,709 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,710 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,710 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,712 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,712 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,713 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,713 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,715 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,715 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,716 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,717 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,718 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,719 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,720 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,720 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,722 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,722 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,723 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,724 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,725 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,726 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,727 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,728 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,730 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,730 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,732 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,732 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,734 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,734 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,735 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,735 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,738 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,738 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,740 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,740 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,753 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,754 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,755 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,756 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,757 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,758 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,770 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,771 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,771 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,772 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,773 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,774 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,775 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,776 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,777 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,778 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,779 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,780 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,783 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,784 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,785 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,799 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,809 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,811 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,818 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,819 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,820 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,821 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,825 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,827 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,829 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,830 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,831 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,832 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,833 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,834 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,835 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,836 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,840 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,841 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,844 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,844 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,846 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,846 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,847 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,848 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,849 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,850 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,851 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,851 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,853 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,853 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,854 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,855 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,857 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,858 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,859 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,859 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,860 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,861 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,862 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,863 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,864 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,865 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,866 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,866 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,868 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,868 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,870 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,870 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,871 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,872 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,873 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,873 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,876 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,881 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,883 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,883 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,885 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,886 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,887 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,887 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:17,889 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:17,889 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,080 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,081 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,083 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,084 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,085 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,087 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,087 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,088 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,090 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,091 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,092 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,092 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,096 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,097 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,099 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,100 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,101 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,101 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,105 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,106 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,107 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,119 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,128 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,135 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,140 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,141 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,143 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,144 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,145 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,146 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,147 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,147 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,152 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,157 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,159 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,160 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,162 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,162 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,163 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,164 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,165 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,166 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,166 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,167 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,168 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,169 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,169 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,170 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,172 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,172 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,174 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,174 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,176 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,176 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,177 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,178 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,179 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,180 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,181 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,181 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,183 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,183 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,185 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,185 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,186 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,187 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,188 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,189 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,191 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,191 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,192 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,193 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,195 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,195 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,199 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,204 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,208 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,208 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,209 - __main__ - INFO - 按交易所分析完成，结果已保存到 d:\ifindata\第一次小组作业\output\companies_by_exchange.csv 和 d:\ifindata\第一次小组作业\output\companies_by_exchange.png
# 2025-05-25 21:55:18,210 - __main__ - INFO - 分析行业分布...
# 2025-05-25 21:55:18,211 - __main__ - INFO - 检查目录: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:18,212 - __main__ - INFO - 目录写入权限检查通过: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:18,213 - __main__ - INFO - 目录已存在且可写: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:18,228 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,228 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,230 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,230 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,232 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,232 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,233 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,234 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,235 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,237 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,239 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,239 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,246 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,247 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,248 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,249 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,250 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,250 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,251 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,252 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,253 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,253 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,254 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,255 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,259 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,266 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,287 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,288 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,289 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,289 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,295 - __main__ - INFO - 检查目录: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:18,297 - __main__ - INFO - 目录写入权限检查通过: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:18,298 - __main__ - INFO - 目录已存在且可写: d:\ifindata\第一次小组作业\output
# 2025-05-25 21:55:18,310 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,310 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,311 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,312 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,313 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,313 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,314 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,315 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,316 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,316 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,318 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,318 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,319 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,320 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,323 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,324 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,324 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,325 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,326 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,326 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,329 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,330 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,331 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,331 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,333 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,333 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,335 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,335 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,340 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:18,340 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:18,380 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# ...
# 2025-05-25 21:55:19,757 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,758 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,759 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,759 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,760 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,761 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,762 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,762 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,766 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,767 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,768 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,769 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,770 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,770 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,777 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,778 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,779 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,780 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,781 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,781 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,782 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,783 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,784 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,785 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,787 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,787 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,789 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,790 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,791 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,792 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,795 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,796 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,797 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,797 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,800 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,806 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,808 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,808 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,810 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,810 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,814 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,824 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,839 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,840 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,841 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,842 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,843 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,843 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,845 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,845 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,846 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,850 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,857 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,857 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,860 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,860 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,862 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,862 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,863 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,864 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,865 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,865 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:19,866 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:19,867 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,107 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,108 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,109 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,109 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,111 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,112 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,112 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,113 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,114 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,114 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,115 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,116 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,116 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,118 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,119 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,119 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,121 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,121 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,122 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,122 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,126 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,126 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,127 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,128 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,129 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,129 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,132 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,133 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,134 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,135 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,136 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,136 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,137 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,138 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,139 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,140 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,142 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,143 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,148 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,152 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,157 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,159 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,164 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,170 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,171 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,172 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,175 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,176 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,177 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,177 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,179 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,179 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,180 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,181 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,182 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,183 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,186 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,187 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,189 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,189 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,191 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,191 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,192 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,193 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,197 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,197 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,199 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,200 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,201 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,201 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,202 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,203 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,204 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,205 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,206 - matplotlib.font_manager - WARNING - findfont: Font family 'WenQuanYi Micro Hei' not found.
# 2025-05-25 21:55:20,207 - matplotlib.font_manager - WARNING - findfont: Font family 'Heiti TC' not found.
# 2025-05-25 21:55:20,210 - __main__ - INFO - 行业分布分析完成，结果已保存到 d:\ifindata\第一次小组作业\output 目录
# 2025-05-25 21:55:20,211 - __main__ - INFO - ==================================================
# 2025-05-25 21:55:20,212 - __main__ - INFO - 分析完成！所有结果已保存到 output 目录
# 2025-05-25 21:55:20,212 - __main__ - INFO - ==================================================
